# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(14,6), facecolor='tan', dpi=80)
plt.subplot(2, 2, 1, facecolor='green')
plt.subplot(2, 2, 2)
plt.subplot(2, 2, 3)
plt.subplot(2, 2, 4)

plt.figure(figsize=(14,6), dpi=80)

plt.subplot(1, 2, 1)
plt.subplot(1, 2, 2)


plt.show()
